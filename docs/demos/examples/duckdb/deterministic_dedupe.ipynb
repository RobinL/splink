# %% [markdown]
# ## Linking a dataset of real historical persons with Deterrministic Rules
#
# While Splink is primarily a tool for probabilistic records linkage, it includes functionality to perform deterministic (i.e. rules based) linkage.
#
# Significant work has gone into optimising the performance of rules based matching, so Splink is likely to be significantly faster than writing the basic SQL by hand.
#
# In this example, we deduplicate a 50k row dataset based on historical persons scraped from wikidata. Duplicate records are introduced with a variety of errors introduced. The probabilistic dedupe of the same dataset can be found at `Deduplicate 50k rows historical persons`.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/RobinL/splink/blob/ipynbs/docs/demos/examples/duckdb/deterministic_dedupe.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# Uncomment and run this cell if you're running in Google Colab.
# !pip install "splink[altair,igraph,pyarrow] @ git+https://github.com/RobinL/splink.git@master"

# %%
from splink import splink_datasets
from splink import DuckDBAPI

df = splink_datasets.historical_50k
db_api = DuckDBAPI()
df_sdf = db_api.register(df)
df_sdf.as_duckdbpyrelation().limit(5).show(max_width=10000)
# Out:
# ┌────────────┬──────────┬──────────────────────────────────────────────────┬───────────────────┬────────────┬───────────┬────────────┬─────────────┬───────────────┬─────────┬────────────┐
# │ unique_id  │ cluster  │                    full_name                     │ first_and_surname │ first_name │  surname  │    dob     │ birth_place │ postcode_fake │ gender  │ occupation │
# │  varchar   │ varchar  │                     varchar                      │      varchar      │  varchar   │  varchar  │  varchar   │   varchar   │    varchar    │ varchar │  varchar   │
# ├────────────┼──────────┼──────────────────────────────────────────────────┼───────────────────┼────────────┼───────────┼────────────┼─────────────┼───────────────┼─────────┼────────────┤
# │ Q2296770-1 │ Q2296770 │ thomas clifford, 1st baron clifford of chudleigh │ thomas chudleigh  │ thomas     │ chudleigh │ 1630-08-01 │ devon       │ tq13 8df      │ male    │ politician │
# │ Q2296770-2 │ Q2296770 │ thomas of chudleigh                              │ thomas chudleigh  │ thomas     │ chudleigh │ 1630-08-01 │ devon       │ tq13 8df      │ male    │ politician │
# │ Q2296770-3 │ Q2296770 │ tom 1st baron clifford of chudleigh              │ tom chudleigh     │ tom        │ chudleigh │ 1630-08-01 │ devon       │ tq13 8df      │ male    │ politician │
# │ Q2296770-4 │ Q2296770 │ thomas 1st chudleigh                             │ thomas chudleigh  │ thomas     │ chudleigh │ 1630-08-01 │ devon       │ tq13 8hu      │ NULL    │ politician │
# │ Q2296770-5 │ Q2296770 │ thomas clifford, 1st baron chudleigh             │ thomas chudleigh  │ thomas     │ chudleigh │ 1630-08-01 │ devon       │ tq13 8df      │ NULL    │ politician │
# └────────────┴──────────┴──────────────────────────────────────────────────┴───────────────────┴────────────┴───────────┴────────────┴─────────────┴───────────────┴─────────┴────────────┘

# %% [markdown]
# When defining the settings object, specity your deterministic rules in the `blocking_rules_to_generate_predictions` key.
#
# For a deterministic linkage, the linkage methodology is based solely on these rules, so there is no need to define `comparisons` nor any other parameters required for model training in a probabilistic model.

# %% [markdown]
# Prior to running the linkage, it's usually a good idea to check how many record comparisons will be generated by your deterministic rules:

# %%
from splink import DuckDBAPI, block_on
from splink.blocking_analysis import (
    chart_comparisons_from_blocking_rules,
)


chart_comparisons_from_blocking_rules(
    df_sdf,
    blocking_rules=[
        block_on("first_name", "surname", "dob"),
        block_on("surname", "dob", "postcode_fake"),
        block_on("first_name", "dob", "occupation"),
    ],
    link_type="dedupe_only",
    record_sample_proportion=0.2,
)
# Out:
# /home/runner/work/splink/splink/splink/internals/blocking_analysis.py:668: UserWarning: The sampled blocking analysis estimate for blocking rule '(l."surname" = r."surname") AND (l."dob" = r."dob") AND (l."postcode_fake" = r."postcode_fake")' is based on 345 sampled pairwise comparisons. This is below the recommended minimum of 1,000, so the estimate may be unstable. Increase record_sample_proportion for a more stable estimate.
#   return _cumulative_comparisons_to_be_scored_from_blocking_rules(
# /home/runner/work/splink/splink/splink/internals/blocking_analysis.py:668: UserWarning: The sampled blocking analysis estimate for blocking rule '(l."first_name" = r."first_name") AND (l."dob" = r."dob") AND (l."occupation" = r."occupation")' is based on 163 sampled pairwise comparisons. This is below the recommended minimum of 1,000, so the estimate may be unstable. Increase record_sample_proportion for a more stable estimate.
#   return _cumulative_comparisons_to_be_scored_from_blocking_rules(
# SplinkChart (use .to_html() or .save() to export HTML)

# %%
from splink import Linker, SettingsCreator

settings = SettingsCreator(
    link_type="dedupe_only",
    blocking_rules_to_generate_predictions=[
        block_on("first_name", "surname", "dob"),
        block_on("surname", "dob", "postcode_fake"),
        block_on("first_name", "dob", "occupation"),
    ],
    retain_intermediate_calculation_columns=True,
)

linker = Linker(df_sdf, settings)

# %% [markdown]
# The results of the linkage can be viewed with the `deterministic_link` function.

# %%
df_predict = linker.inference.deterministic_link()
df_predict.as_duckdbpyrelation().limit(5).show(max_width=10000)
# Out:
# Blocking time: 0.05 seconds
# ┌─────────────┬─────────────┬─────────────────┬─────────────────┬────────────┬────────────┬───────────┬───────────┬──────────────┬──────────────┬──────────────┬──────────────┬───────────┐
# │ unique_id_l │ unique_id_r │ postcode_fake_l │ postcode_fake_r │   dob_l    │   dob_r    │ surname_l │ surname_r │ first_name_l │ first_name_r │ occupation_l │ occupation_r │ match_key │
# │   varchar   │   varchar   │     varchar     │     varchar     │  varchar   │  varchar   │  varchar  │  varchar  │   varchar    │   varchar    │   varchar    │   varchar    │  varchar  │
# ├─────────────┼─────────────┼─────────────────┼─────────────────┼────────────┼────────────┼───────────┼───────────┼──────────────┼──────────────┼──────────────┼──────────────┼───────────┤
# │ Q21459554-5 │ Q21459554-9 │ ng1 5dn         │ ng7 1bu         │ 1860-01-01 │ 1860-01-01 │ small     │ small     │ florence     │ florence     │ NULL         │ painter      │ 0         │
# │ Q29033779-1 │ Q29033779-2 │ st16 3wj        │ st16 3wj        │ 1850-07-15 │ 1850-07-15 │ bromley   │ bromley   │ albert       │ albert       │ NULL         │ NULL         │ 0         │
# │ Q16228740-1 │ Q16228740-2 │ l8 0xz          │ l8 0xz          │ 1855-01-01 │ 1855-01-01 │ vance     │ vance     │ j.           │ j.           │ archer       │ archer       │ 0         │
# │ Q5344622-1  │ Q5344622-3  │ sk11 0ja        │ NULL            │ 1862-06-17 │ 1862-06-17 │ nicholl   │ nicholl   │ edward       │ edward       │ NULL         │ NULL         │ 0         │
# │ Q5344622-2  │ Q5344622-3  │ tf9 3jt         │ NULL            │ 1862-06-17 │ 1862-06-17 │ nicholl   │ nicholl   │ edward       │ edward       │ NULL         │ NULL         │ 0         │
# └─────────────┴─────────────┴─────────────────┴─────────────────┴────────────┴────────────┴───────────┴───────────┴──────────────┴──────────────┴──────────────┴──────────────┴───────────┘

# %% [markdown]
# Which can be used to generate clusters.
#
# Note, for deterministic linkage, each comparison has been assigned a match probability of 1, so to generate clusters, set `threshold_match_probability=1` in the `cluster_pairwise_predictions_at_threshold` function.

# %%
clusters = linker.clustering.cluster_pairwise_predictions_at_threshold(
    df_predict
)
# Out:
# Completed iteration 1, num edges remaining to process: 2260
# Completed iteration 2, num edges remaining to process: 64
# Completed iteration 3, num edges remaining to process: 0

# %%
clusters.as_duckdbpyrelation().limit(5).show(max_width=10000)
# Out:
# ┌──────────────┬──────────────┬───────────┬──────────────────────────────────┬─────────────────────┬────────────┬───────────┬────────────┬───────────────────────────┬───────────────┬─────────┬────────────┐
# │  cluster_id  │  unique_id   │  cluster  │            full_name             │  first_and_surname  │ first_name │  surname  │    dob     │        birth_place        │ postcode_fake │ gender  │ occupation │
# │   varchar    │   varchar    │  varchar  │             varchar              │       varchar       │  varchar   │  varchar  │  varchar   │          varchar          │    varchar    │ varchar │  varchar   │
# ├──────────────┼──────────────┼───────────┼──────────────────────────────────┼─────────────────────┼────────────┼───────────┼────────────┼───────────────────────────┼───────────────┼─────────┼────────────┤
# │ Q2296770-10  │ Q2296770-10  │ Q2296770  │ thomas clifford, baron chudleigh │ thomas chudleigh    │ thomas     │ chudleigh │ NULL       │ devon                     │ tq13 8jr      │ male    │ politician │
# │ Q2296770-15  │ Q2296770-15  │ Q2296770  │ clifford, 1st of chudleigh       │ clifford, chudleigh │ clifford,  │ chudleigh │ 1630-08-01 │ west devon                │ NULL          │ NULL    │ NULL       │
# │ Q2516590-4   │ Q2516590-4   │ Q2516590  │ will whitehead watts             │ will watts          │ will       │ watts     │ NULL       │ shropshire                │ sy5 7nt       │ male    │ geologist  │
# │ Q2516590-6   │ Q2516590-6   │ Q2516590  │ willie watts                     │ willie watts        │ willie     │ watts     │ NULL       │ shropshire                │ NULL          │ male    │ geologist  │
# │ Q55455287-15 │ Q55455287-15 │ Q55455287 │ john vickers                     │ john vickers        │ john       │ vickers   │ 1886-01-01 │ somerset west and taunton │ NULL          │ NULL    │ NULL       │
# └──────────────┴──────────────┴───────────┴──────────────────────────────────┴─────────────────────┴────────────┴───────────┴────────────┴───────────────────────────┴───────────────┴─────────┴────────────┘

# %% [markdown]
# These results can then be passed into the `Cluster Studio Dashboard`.

# %%
linker.visualisations.cluster_studio_dashboard(
    df_predict,
    clusters,
    "dashboards/50k_deterministic_cluster.html",
    sampling_method="by_cluster_size",
    overwrite=True,
)

from IPython.display import IFrame

IFrame(src="./dashboards/50k_deterministic_cluster.html", width="100%", height=1200)
# Out:
#         <iframe
#             width="100%"
#             height="1200"
#             src="./dashboards/50k_deterministic_cluster.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
